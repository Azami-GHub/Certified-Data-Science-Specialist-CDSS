# %% [markdown]
# # **1. Python Syntax**
#
# ![python-syntax-2-.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# In every programming language, you will come along the word ***syntax***. A programming syntax refers to ***a set of rules***.
#
# When we run a Python program, first it is read by a ***parser***. The parser will only understand the Python code if it is according to the ***predefined rules of Python programming*** otherwise it will give you syntax errors. That is why it is important to understand the syntax of the language.

# %% [markdown]
# Types of Syntax Structures in Python:
#
#   1.1   Line structure
#
#   1.2   Multiline Statements
#
#   1.3   Multiple Statements in one line
#
#   1.4   Quotations
#
#   1.5   Identifier
#
#   1.6   User inputs

# %% [markdown]
# ***1.1 Line structure***

# %% [markdown]
# Msg refers to a variable

# %%
Message = "Hi! Welcome to the Python Workshop Azami"
print(Message)
# Out:
# Hi! Welcome to the Python Workshop Azami

# %%
number1 = "5"   #string
number2 = 5     #integer

print(number1)
print(number2)
# Out:
# 5
# 5

# %% [markdown]
# # Python Day 1

# %% [markdown]
# Basic syntax of Python

# %% [markdown]
# ***1.2 Multiline Statements***

# %%
print("Hi! \
How are you today? \
What are you planning this Sunday? \
")
# Out:
# Hi! How are you today? What are you planning this Sunday?

# %%
print("Hi!
How are you today?
What are you planning this Sunday?
")
# Out:
#   File "<ipython-input-5-9b21ebe78c40>", line 1
#     print("Hi!
#                ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# ***1.3 Multiline Statements in one line***

# %%
num1 = 10; num2 = 20; print ("Sum of numbers = ", num1+num2)
# Out:
# Sum of numbers =  30

# %%
num1 = 50; num2 = 20; print ("Sum of numbers = ", num1-num2)
# Out:
# Sum of numbers =  30

# %% [markdown]
# ***1.4 Quotations***

# %%
message1 = "Hey"
message2 = 'Hey'
print(message1)
print(message2)
# Out:
# Hey
# Hey

# %%
print("Hey 'Kamal' ")
print('Hey "Kamal" ')
# Out:
# Hey 'Kamal'
# Hey "Kamal"

# %% [markdown]
# ***1.5 Identifier/ variable***
#
# A program contains variables, functions, classes, modules, packages etc. Identifier is the name given to these programming elements. There are some rules which we have to keep in mind for creating an identifier.
#
# * Identifier can only begin with characters starting from A-Z (Uppercase
#
#   letters), a-z (lowercase letters) or _ (underscore).
#
# * They can be then followed by any number of letters, digits or underscores.
#
# * Python is case sensitive language so the identifiers ‘count’ and ‘Count’ are two different identifiers.
#
# * Python Reserved keywords like for, global, continue, break, etc. cannot be used as identifiers.
#
# *Examples of Valid Identifiers:*
#
# * name
# * _3name6
#
# * get_all_names
#
# * YES
#
# *Examples of Invalid Identifiers:*
#
# * 1name
#
# * name$
#
# * get-score

# %% [markdown]
# ***1.6 User inputs***

# %%
Msg = input() #input is the function
print(Msg)
# Out:
# 1234abc
# 1234abc

# %% [markdown]
# # **2. Comments**

# %% [markdown]
# ![wf_120314_LastWord_Comments680x300.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# To add notes or explanations of the code. Comments are just for reading and Python interpreter ignores whatever we write in comments.

# %% [markdown]
# **Single-Line Comments**

# %%
print ("Today is Monday")
#First day of programming class
# Out:
# Today is Monday

# %% [markdown]
# **Multiline Comments (triple-double quotes)**

# %%
"""
This is a tutorial
to write comments
in Python
"""

print ("Today is Monday")
# Out:
# Today is Monday

# %% [markdown]
# # **3. Variables**

# %% [markdown]
# ![python-variables.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Variables are containers for storing data values.
#
# Python has no command for declaring a variable. A variable is created the moment you first assign a value to it.

# %%
x = 5
y = "John"
print(x)
print(y)
# Out:
# 5
# John

# %% [markdown]
# *If you want to specify the data type of a variable, this can be done with casting.*

# %%
x = str(3)    # x will be '3' (string for text)
y = int(3)    # y will be 3 (integer for numbers)
z = float(3)  # z will be 3.0 (decimal values)

print(x)
print(y)
print(z)
# Out:
# 3
# 3
# 3.0

# %% [markdown]
# *You can get the data type of a variable with the type() function.*

# %%
x = 5
y = "John"

print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# Assign three variables A, B and C. Create random numbers for all three variables. For A, set the data type as "str" whereas for B and C set the datatype as "int". Perform any arithmatic operations using combination of A, B and C.

# %%
A = str(3)    # x will be '3' (string for text)
B = int(5)    # y will be 3 (integer for numbers)
C = float(7)
D = str(10)

x = A + D #CONCATENATION
y = B * C

print(x)
print(type(x))
print(y)
# Out:
# 310
# <class 'str'>
# 35.0

# %% [markdown]
# String variables can be declared either by using single or double quotes:

# %%
x = "John"
print(x)
#double quotes are the same as single quotes:
x = 'John'
print(x)
# Out:
# John
# John

# %% [markdown]
# Variable names are case-sensitive

# %%
a = 4
A = "Sally"
#A will not overwrite a
print(a)
print(A)
# Out:
# 4
# Sally

# %% [markdown]
# # **4. Functions**

# %% [markdown]
# # ![maxresdefault.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# A function is a block of code which only runs when it is called.
#
# You can pass data, known as parameters, into a function.
#
# A function can return data as a result.

# %% [markdown]
# # **Calling a Function**
#
# In Python a function is defined using the def keyword:
#
# To call a function, use the function name followed by parenthesis:

# %%
def my_function():   #STEP 1 define
 print("Hi I am learning Python")  #STEP 2 input

my_function()  #STEP 3 call the function
# Out:
# Hi I am learning Python

# %% [markdown]
# ## **Arguments**
# Information can be passed into functions as arguments. The following example has a function with one argument (fname). When the function is called, we pass along a first name, which is used inside the function to print the full phrase:

# %%
def my_function(fname):
  print(fname + "TRAINING 1" ) #+ symbol here is to concatenate

my_function("Notebook of ")
my_function("Functions in ")
my_function("Modules in ")
# Out:
# Notebook of TRAINING 1
# Functions in TRAINING 1
# Modules in TRAINING 1

# %%
def my_function(fname):
  print(fname + "    TRAINING 1" ) #+ symbol here is to concatenate

my_function("Notebook of ")
my_function("Functions in ")
my_function("Modules in ")
# Out:
# Notebook of     TRAINING 1
# Functions in     TRAINING 1
# Modules in     TRAINING 1

# %%
def testFunc(testVar):
    print(testVar + " rumah")

testFunc("Saya makan di")
testFunc("Saya tidur di")
testFunc("Saya baru balik")
# Out:
# Saya makan di rumah
# Saya tidur di rumah
# Saya baru balik rumah

# %%
#area of cube
#6a^2

def varVolCube(a):
    print("The area of a cube " + str(6*a^2))

varVolCube(10)
# Out:
# The area of a cube 62

# %%
def varVolCube(a,b,c):
    print("The volume of a cube ",(a*b*c))

varVolCube(10,10,10)
# Out:
# The volume of a cube  1000

# %% [markdown]
# # **5. Data Types**

# %% [markdown]
# In programming, data type is an important concept.
#
# Variables can store data of different types, and different types can do different things.
#
# Python has the following data types built-in by default, in these categories:
#
# Text Type: str
#
# Numeric Types: int, float, complex
#
# Sequence Types: list, tuple, range
#
# Mapping Type: dict
#
# Set Types: set, frozenset
#
# boolean Type: bool
#
# Binary Types: bytes, bytearray, memoryview

# %% [markdown]
# If you want to specify the data type, you can use the following constructor functions:
#
# LET'S TRY THIS!
#
# x = str("I am good")
#
# x = int(20)
#
# x = float(20.5)
#
# x = complex(1j)
#
# x = list(("apple", "banana", "cherry"))
#
# x = tuple(("apple", "banana", "cherry"))
#
# x = range(6)
#
# x = dict(name="John", age=36)
#
# x = set(("apple", "banana", "cherry"))
#
# x = frozenset(("apple", "banana", "cherry"))
#
# x = bool(5)
#
# x = bytes(5)
#
# x = bytearray(5)
#
# x = memoryview(bytes(5))
