# %% [markdown]
# Natural Language Processing
#
# 1. Split feature and target
# 2. Tokenization
# 3. Bag of Words (BoW)
# 4. n grams
# 5. tfidf
#
# 6. PREDICT

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/CDSS/Data Folder/Womens Clothing E-Commerce Reviews.csv', encoding ="utf8")
df = df.sample(frac=1, random_state=10) #to create a random environment
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.head()
# Out:
#        Unnamed: 0  Clothing ID  Age                   Title  \
# 9170         9170          862   36                     Fun
# 9346         9346          895   31             Great tunic
# 6249         6249          836   42                     NaN
# 17481       17481         1086   45      Feels like a dream
# 5204         5204          854   44  This top surprised me!
#
#                                              Review Text  Rating  \
# 9170   These tanks are perfect for working out! they ...       4
# 9346   I love this tunic. i am 22 weeks pregnant and ...       5
# 6249   Fit is boxy yet flattering and material is she...       5
# 17481  This dress is so soft, flowy and comfortable! ...       5
# 5204   This too is easy to wear, skins the body nicel...       5
#
#        Recommended IND  Positive Feedback Count Division Name Department Name  \
# 9170                 1                        0       General            Tops
# 9346                 1                        0       General            Tops
# 6249                 1                        0       General            Tops
# 17481                1                        1       General         Dresses
# 5204                 1                        1       General            Tops
#
#        Class Name
# 9170        Knits
# 9346   Fine gauge
# 6249      Blouses
# 17481     Dresses
# 5204        Knits

# %%
len(df)
# Out:
# 23486

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23486 entries, 9170 to 17673
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               23486 non-null  int64
#  1   Clothing ID              23486 non-null  int64
#  2   Age                      23486 non-null  int64
#  3   Title                    19676 non-null  object
#  4   Review Text              22641 non-null  object
#  5   Rating                   23486 non-null  int64
#  6   Recommended IND          23486 non-null  int64
#  7   Positive Feedback Count  23486 non-null  int64
#  8   Division Name            23472 non-null  object
#  9   Department Name          23472 non-null  object
#  10  Class Name               23472 non-null  object
# dtypes: int64(6), object(5)
# memory usage: 2.2+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                    0
# Clothing ID                   0
# Age                           0
# Title                      3810
# Review Text                 845
# Rating                        0
# Recommended IND               0
# Positive Feedback Count       0
# Division Name                14
# Department Name              14
# Class Name                   14
# dtype: int64

# %%
df.Rating.unique()
# Out:
# array([4, 5, 3, 2, 1])

# %%
# Drop missing values
df.dropna(inplace=True)

# Remove any 'neutral' ratings equal to 3
df = df[df['Rating'] != 3]

# Encode 4s and 5s as 1 (rated positively)
# Encode 1s and 2s as 0 (rated poorly)
# if greater than 3, make it as 1, otherwise 0
df['Positively Rated'] = np.where(df['Rating'] > 3, 1, 0)
# Out:
# <ipython-input-54-663725b7b186>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Positively Rated'] = np.where(df['Rating'] > 3, 1, 0)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# Clothing ID                0
# Age                        0
# Title                      0
# Review Text                0
# Rating                     0
# Recommended IND            0
# Positive Feedback Count    0
# Division Name              0
# Department Name            0
# Class Name                 0
# Positively Rated           0
# dtype: int64

# %%
df.head()
# Out:
#        Unnamed: 0  Clothing ID  Age                   Title  \
# 9170         9170          862   36                     Fun
# 9346         9346          895   31             Great tunic
# 17481       17481         1086   45      Feels like a dream
# 5204         5204          854   44  This top surprised me!
# 22682       22682          862   62   Gorgeously draped top
#
#                                              Review Text  Rating  \
# 9170   These tanks are perfect for working out! they ...       4
# 9346   I love this tunic. i am 22 weeks pregnant and ...       5
# 17481  This dress is so soft, flowy and comfortable! ...       5
# 5204   This too is easy to wear, skins the body nicel...       5
# 22682  This top is extremely well made. the fabric is...       5
#
#        Recommended IND  Positive Feedback Count   Division Name  \
# 9170                 1                        0         General
# 9346                 1                        0         General
# 17481                1                        1         General
# 5204                 1                        1         General
# 22682                1                        4  General Petite
#
#       Department Name  Class Name  Positively Rated
# 9170             Tops       Knits                 1
# 9346             Tops  Fine gauge                 1
# 17481         Dresses     Dresses                 1
# 5204             Tops       Knits                 1
# 22682            Tops       Knits                 1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17198 entries, 9170 to 7293
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               17198 non-null  int64
#  1   Clothing ID              17198 non-null  int64
#  2   Age                      17198 non-null  int64
#  3   Title                    17198 non-null  object
#  4   Review Text              17198 non-null  object
#  5   Rating                   17198 non-null  int64
#  6   Recommended IND          17198 non-null  int64
#  7   Positive Feedback Count  17198 non-null  int64
#  8   Division Name            17198 non-null  object
#  9   Department Name          17198 non-null  object
#  10  Class Name               17198 non-null  object
#  11  Positively Rated         17198 non-null  int64
# dtypes: int64(7), object(5)
# memory usage: 1.7+ MB

# %% [markdown]
# # Model Selection in scikit-learn

# %%
from sklearn.model_selection import train_test_split

# Split data into train and test subsets
X_train, X_test, y_train, y_test = train_test_split(df['Review Text'],
                                                    df['Positively Rated'],
                                                    random_state=0)

# %%
print( X_train.iloc[2])
# Out:
# Disappointed :-(
# this top has a boxy shape and looked like a mini moo moo on me. i have a similar shape as the model and it looked nothing like that on me. bummer! i liked the quality and weight (not too heavy nor too light) but shape is unflattering. it's going back.

# %%
X_train.shape
# Out:
# (12898,)

# %%
X_test.shape
# Out:
# (4300,)

# %% [markdown]
# # Extracting features from text files
#
#
# Text files are actually series of words (ordered). In order to run machine learning algorithms we need to convert the text files into numerical feature vectors. We will be using bag of words model.
#
# ## Bag-of-words (BOW)
# BOW model allows us to represent text as numerical feature vectors. The idea behind BOW is quite simple and can be summarized as follows:
# - 1) Create a vocabulary of unique tokens (or words) from the entire set
#     of documents.
# - 2) Construct a feature vector from each document that contains the counts of how often each word occurs in the particular document.
#
# Since the unique words in each document represent only a small subset of all the words in the bag-of-words vocabulary, the feature vectors will consist of mostly zeros, which is why we call them sparse. For this reason we say that bags of words are typically <b>high-dimensional sparse datasets</b>.
#
# {for our example. Briefly, we segment each text file into words (for English splitting by space), and count # of times each word occurs in each document and finally assign each word an integer id. Each unique word in our dictionary will correspond to a feature (descriptive feature).}
#
#
# ### Transform words into vectors (CountVectorizer)
# To construct a bag-of-words model based on the word counts in the respective documents, we can use the `CountVectorizer` class implemented in `scikit-learn`. As we will see in the following codes, the `CountVectorizer` class takes an array of text data, which can be documents or just sentences, and constructs the bag-of-words model for us:
#
# Scikit-learn has a high level component which will create feature vectors for us <b>‘CountVectorizer’</b>

# %%
from sklearn.feature_extraction.text import CountVectorizer

docs = np.array([
    'The sun is shining',
    'The weather is sweet',
    'The sun is shining and the weather is sweet'])

# Fit the CountVectorizer to the training data
vect1=CountVectorizer().fit(docs)

# transform the documents in the training data to a document-term matrix.
bag1 = vect1.transform(docs)

#vector is number format

# %%
vect1.vocabulary_
# Out:
# {'the': 5, 'sun': 3, 'is': 1, 'shining': 2, 'weather': 6, 'sweet': 4, 'and': 0}

# %%
vect1.get_feature_names_out()
# Out:
# array(['and', 'is', 'shining', 'sun', 'sweet', 'the', 'weather'],
#       dtype=object)

# %% [markdown]
# ## <font color=green> Exercise A</font>
#
# 1) Do CountVectorizer for training data
#
# 2) Determine:
# - The number of features
# - The shape of sparse matrix

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Fit the CountVectorizer to the training data
review1 = CountVectorizer().fit(X_train)

# transform the documents in the training data to a document-term matrix.
X_train_vectorized1 = review1.transform(X_train)


print(len(review1.get_feature_names_out()))
X_train_vectorized1.shape

# for BOW, raw data is review1, and bag is vectorized1
# output
# (num of observation, num of columns/keywords)
# Out:
# 11436
# (12898, 11436)

# %%
X_test_vectorized1 = review1.transform(X_test)
X_test_vectorized1.shape
# Out:
# (4300, 11436)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# Split data into train and test subsets
X_train, X_test, y_train, y_test = train_test_split(df['Review Text'],
                                                    df['Positively Rated'],
                                                    random_state=0)

# Train the Logistic Regression model
lm = LogisticRegression()
lm.fit(X_train_vectorized1, y_train)

# Evaluate the model on the test data
accuracy = lm.score(X_test_vectorized1, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9279069767441861
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
review1.vocabulary_
# Out:
# {'love': 5974,
#  'these': 10141,
#  'pants': 7145,
#  'they': 10143,
#  'are': 883,
#  'so': 9245,
#  'soft': 9259,
#  'and': 761,
#  'comfortable': 2290,
#  'do': 3191,
#  'not': 6754,
#  'fall': 3825,
#  'down': 3238,
#  'like': 5813,
#  'low': 5987,
#  'rise': 8375,
#  'trousers': 10451,
#  'the': 10114,
#  'length': 5749,
#  'for': 4188,
#  'wearing': 11030,
#  'with': 11214,
#  'flats': 4050,
#  'most': 6485,
#  'wide': 11153,
#  'bottom': 1511,
#  'too': 10310,
#  'long': 5908,
#  'very': 10852,
#  'casual': 1879,
#  'to': 10283,
#  'be': 1190,
#  'worn': 11274,
#  'absolutely': 457,
#  'this': 10172,
#  'sweater': 9875,
#  'because': 1224,
#  'it': 5355,
#  'is': 5341,
#  'pretty': 7689,
#  'while': 11117,
#  'being': 1255,
#  'am': 725,
#  'purchased': 7849,
#  'small': 9172,
#  'falls': 3831,
#  'little': 5874,
#  'below': 1272,
#  'my': 6568,
#  'hips': 4864,
#  'color': 2244,
#  'matches': 6168,
#  'everything': 3654,
#  'pockets': 7511,
#  'details': 3005,
#  'add': 540,
#  'nice': 6687,
#  'touch': 10343,
#  'longer': 5909,
#  'sleeves': 9104,
#  'cozy': 2600,
#  'only': 6889,
#  'drawback': 3281,
#  'pills': 7405,
#  'sheds': 8822,
#  'disappointed': 3103,
#  'top': 10314,
#  'has': 4715,
#  'boxy': 1533,
#  'shape': 8798,
#  'looked': 5919,
#  'mini': 6345,
#  'moo': 6467,
#  'on': 6880,
#  'me': 6212,
#  'have': 4729,
#  'similar': 8993,
#  'as': 931,
#  'model': 6422,
#  'nothing': 6762,
#  'that': 10112,
#  'bummer': 1683,
#  'liked': 5814,
#  'quality': 7889,
#  'weight': 11068,
#  'heavy': 4775,
#  'nor': 6743,
#  'light': 5797,
#  'but': 1721,
#  'unflattering': 10656,
#  'going': 4492,
#  'back': 1078,
#  'fell': 3920,
#  'in': 5115,
#  'online': 6888,
#  'obsessed': 6818,
#  'flounce': 4117,
#  'detail': 3002,
#  'sleeve': 9101,
#  'slight': 9121,
#  'line': 5836,
#  'of': 6844,
#  'body': 1448,
#  'was': 10982,
#  'able': 443,
#  'try': 10465,
#  'store': 9590,
#  'glad': 4450,
#  'did': 3042,
#  'ended': 3534,
#  'up': 10733,
#  'sizing': 9043,
#  'from': 4285,
#  'usually': 10780,
#  'still': 9561,
#  'put': 7873,
#  'true': 10453,
#  'size': 9037,
#  'think': 10159,
#  'forgiving': 4207,
#  'cut': 2745,
#  'allows': 694,
#  'work': 11256,
#  'multiple': 6538,
#  'sizes': 9041,
#  'even': 3637,
#  'tried': 10434,
#  'medium': 6238,
#  'fit': 4008,
#  'arms': 903,
#  'bit': 1355,
#  'tight': 10234,
#  'other': 6974,
#  'reviewer': 8320,
#  'mentioned': 6269,
#  'keep': 5497,
#  'mind': 6342,
#  'when': 11106,
#  'choosi': 2053,
#  'ordered': 6948,
#  'regular': 8116,
#  'black': 1367,
#  'loved': 5975,
#  'fabric': 3791,
#  'finish': 3991,
#  'neckline': 6636,
#  'feel': 3912,
#  'order': 6945,
#  'loose': 5938,
#  'look': 5917,
#  'would': 11288,
#  'xl': 11334,
#  'might': 6321,
#  'reorder': 8189,
#  'really': 8005,
#  'hassle': 4717,
#  'will': 11174,
#  'likely': 5815,
#  'wait': 10937,
#  'until': 10720,
#  'another': 790,
#  'free': 4255,
#  'shipping': 8865,
#  'promotion': 7761,
#  'runs': 8484,
#  'short': 8898,
#  'opinion': 6919,
#  'maybe': 6204,
#  'larger': 5634,
#  'more': 6473,
#  'dress': 3302,
#  'huge': 4995,
#  'also': 708,
#  'super': 9804,
#  'thought': 10182,
#  'silly': 8988,
#  'georgette': 4413,
#  'coarse': 2204,
#  'poplin': 7567,
#  'thin': 10155,
#  'cheap': 1980,
#  'went': 11083,
#  'local': 5893,
#  'today': 10286,
#  'something': 9290,
#  'else': 3485,
#  'left': 5727,
#  'cream': 2616,
#  'just': 5474,
#  'simply': 9001,
#  'awesome': 1061,
#  'could': 2557,
#  'felt': 3922,
#  'better': 1300,
#  'between': 1304,
#  'time': 10247,
#  'can': 1802,
#  'say': 8590,
#  'enough': 3561,
#  'good': 4505,
#  'things': 10158,
#  'about': 449,
#  'versatility': 10843,
#  'great': 4578,
#  'piece': 7383,
#  'cooler': 2505,
#  'summer': 9781,
#  'nights': 6706,
#  'cover': 2577,
#  'pilates': 7389,
#  'yoga': 11387,
#  'wear': 11024,
#  'now': 6777,
#  'tempted': 10055,
#  'by': 1748,
#  'teal': 10025,
#  'been': 1236,
#  'looking': 5921,
#  'cuddly': 2704,
#  'yet': 11380,
#  'one': 6882,
#  'anther': 800,
#  'always': 724,
#  'deliver': 2931,
#  'what': 11099,
#  'maternity': 6181,
#  'although': 722,
#  'cool': 2503,
#  'there': 10133,
#  'much': 6526,
#  'material': 6175,
#  'front': 4286,
#  'almost': 698,
#  'ribbed': 8338,
#  'underwear': 10630,
#  'pajama': 7115,
#  'returned': 8298,
#  'such': 9746,
#  'lovely': 5979,
#  'looks': 5923,
#  'customers': 2743,
#  'petal': 7323,
#  'hem': 4797,
#  'part': 7163,
#  'which': 11115,
#  'stretchy': 9652,
#  'clingy': 2162,
#  'isn': 5346,
#  'rich': 8344,
#  'green': 4586,
#  'pic': 7364,
#  've': 10816,
#  'attached': 993,
#  'comparison': 2322,
#  'contrast': 2475,
#  'purposes': 7864,
#  'll': 5883,
#  'way': 11015,
#  'into': 5291,
#  'fir': 3996,
#  'flattering': 4057,
#  'some': 9283,
#  'bras': 1560,
#  'may': 6203,
#  'or': 6937,
#  'show': 8927,
#  'returning': 8299,
#  'smells': 9185,
#  'heavily': 4773,
#  'last': 5646,
#  'purchaser': 7850,
#  'deodorant': 2951,
#  'perfume': 7298,
#  'actually': 536,
#  'nauseating': 6608,
#  'retailer': 8276,
#  'sold': 9270,
#  'full': 4302,
#  'price': 7700,
#  'condition': 2385,
#  'otherwise': 6977,
#  '110': 40,
#  'lbs': 5696,
#  'perfect': 7290,
#  'shirt': 8870,
#  'bought': 1521,
#  'believe': 1259,
#  'reviewers': 8321,
#  'who': 11138,
#  'especially': 3614,
#  'through': 10201,
#  'bust': 1712,
#  'if': 5055,
#  'you': 11395,
#  're': 7980,
#  'busty': 1719,
#  'out': 6987,
#  'wish': 11207,
#  'gotten': 4526,
#  'bigger': 1320,
#  'fence': 3931,
#  'see': 8696,
#  'reasons': 8013,
#  'breathable': 1578,
#  'extremely': 3771,
#  '_________': 426,
#  'pros': 7782,
#  'tons': 10309,
#  'stretch': 9645,
#  '36c': 304,
#  'lot': 5958,
#  'tops': 10323,
#  'snug': 9236,
#  'women': 11233,
#  'however': 4974,
#  'here': 4810,
#  'without': 11220,
#  'go': 4484,
#  'depending': 2954,
#  'how': 4972,
#  'half': 4654,
#  'skirt': 9075,
#  'feels': 3915,
#  'skin': 9061,
#  'breezy': 1587,
#  'layered': 5682,
#  'an': 757,
#  'pleasantly': 7484,
#  'surprised': 9839,
#  'well': 11081,
#  'skims': 9060,
#  'over': 7016,
#  'definitely': 2905,
#  'needs': 6648,
#  'belt': 1273,
#  'comes': 2282,
#  'gorgeous': 4518,
#  'print': 7715,
#  'mom': 6444,
#  'both': 1503,
#  'we': 11019,
#  'different': 3056,
#  'types': 10540,
#  'had': 4644,
#  'large': 5632,
#  'chest': 2012,
#  'she': 8815,
#  'ribcage': 8342,
#  'got': 4524,
#  '10': 10,
#  'normally': 6748,
#  '12': 70,
#  'easier': 3398,
#  'zip': 11421,
#  'seems': 8707,
#  'designed': 2985,
#  'need': 6641,
#  'bra': 1542,
#  'get': 4414,
#  'her': 4809,
#  'straps': 9621,
#  'shortened': 8902,
#  'reference': 8078,
#  'hope': 4924,
#  'helps': 4796,
#  'combination': 2272,
#  'comfort': 2286,
#  'beauty': 1217,
#  'highly': 4845,
#  'recommend': 8041,
#  'cute': 2747,
#  'shoulder': 8921,
#  'kind': 5529,
#  'knew': 5550,
#  'wanted': 10960,
#  'moment': 6445,
#  'saw': 8589,
#  'onto': 6892,
#  'wishlist': 11210,
#  'sale': 8528,
#  'fits': 4009,
#  'beautifully': 1215,
#  'normal': 6746,
#  'already': 705,
#  'coordinating': 2515,
#  'tank': 9983,
#  'compliments': 2358,
#  'whenever': 11107,
#  'hd': 4737,
#  'paris': 7158,
#  'new': 6676,
#  'layer': 5681,
#  'layering': 5683,
#  'wonderful': 11238,
#  'crisp': 2654,
#  'mornings': 6476,
#  'cardigan': 1833,
#  'skinny': 9066,
#  'jeans': 5413,
#  'tee': 10036,
#  'photo': 7351,
#  'shows': 8937,
#  'day': 2815,
#  'want': 10959,
#  'take': 9964,
#  'off': 6845,
#  'cloudy': 2190,
#  'happy': 4699,
#  'purchase': 7848,
#  'delighted': 2926,
#  'does': 3198,
#  'happen': 4693,
#  'often': 6862,
#  'navy': 6612,
#  'tights': 10243,
#  'athletic': 984,
#  'around': 907,
#  'blouse': 1415,
#  'comfy': 2297,
#  'found': 4230,
#  'jumpsuit': 5468,
#  'standard': 9478,
#  'red': 8058,
#  'motif': 6491,
#  'pictures': 7379,
#  'don': 3216,
#  'justice': 5475,
#  'surprise': 9838,
#  'course': 2574,
#  'billowy': 1336,
#  'since': 9005,
#  '113lbs': 49,
#  'came': 1781,
#  'all': 684,
#  'ankles': 778,
#  'where': 11108,
#  'meet': 6241,
#  'feet': 3917,
#  'maxi': 6198,
#  'smocked': 9192,
#  'bodice': 1446,
#  'bubbling': 1654,
#  'area': 884,
#  'near': 6617,
#  'armpits': 902,
#  'ladi': 5604,
#  'excited': 3693,
#  'legs': 5737,
#  'butt': 1724,
#  'waist': 10929,
#  'big': 1318,
#  '24': 213,
#  'wouldn': 11289,
#  'bother': 1504,
#  'hang': 4682,
#  'extra': 3766,
#  'loop': 5934,
#  'hold': 4886,
#  'design': 2984,
#  'higher': 4837,
#  'waisted': 10933,
#  'high': 4835,
#  'no': 6722,
#  'muffin': 6528,
#  'typical': 10542,
#  'ag': 616,
#  'sweat': 9874,
#  'worth': 11282,
#  'money': 6451,
#  'colors': 2254,
#  'blue': 1427,
#  'orange': 6938,
#  'style': 9714,
#  'deeper': 2878,
#  'than': 10105,
#  'appears': 843,
#  'should': 8919,
#  'conscious': 2418,
#  'fluorescent': 4148,
#  'subtly': 9739,
#  'muted': 6563,
#  'pics': 7374,
#  'overall': 7018,
#  'elegance': 3459,
#  'intricate': 5295,
#  'centered': 1924,
#  'were': 11084,
#  'trying': 10467,
#  'save': 8582,
#  'wherever': 11110,
#  'symmetry': 9929,
#  'centering': 1925,
#  'expected': 3726,
#  'appeared': 841,
#  'picture': 7377,
#  'becau': 1222,
#  'worse': 11280,
#  'rehersal': 8123,
#  'dinner': 3080,
#  'received': 8025,
#  'many': 6116,
#  'beautifil': 1210,
#  'made': 6047,
#  '130': 97,
#  'petitte': 7333,
#  'then': 10127,
#  'couldn': 2558,
#  'ensemble': 3564,
#  'anywhere': 827,
#  'makes': 6084,
#  'breathe': 1579,
#  'under': 10600,
#  'its': 5373,
#  'baggy': 1109,
#  'their': 10121,
#  'inside': 5222,
#  'darker': 2799,
#  'rolled': 8406,
#  'ever': 3645,
#  'leggings': 5733,
#  'thick': 10146,
#  'hiding': 4833,
#  'any': 815,
#  'imperfections': 5094,
#  'satin': 8567,
#  'them': 10123,
#  'dressy': 3312,
#  '155': 149,
#  'everywhere': 3656,
#  'hit': 4872,
#  'right': 8360,
#  'ankle': 777,
#  'bone': 1464,
#  'anybody': 816,
#  'job': 5435,
#  'pair': 7110,
#  'pilcro': 7393,
#  'denim': 2943,
#  'shorts': 8912,
#  'reason': 8010,
#  'colored': 2249,
#  'ones': 6883,
#  'white': 11134,
#  'yellow': 11368,
#  'pink': 7416,
#  'completely': 2344,
#  'point': 7513,
#  'sagging': 8518,
#  'hoping': 4931,
#  'coveting': 2587,
#  'person': 7309,
#  'hoped': 4925,
#  'vivid': 10896,
#  'beautiful': 1212,
#  'buttons': 1738,
#  'snugger': 9237,
#  'worked': 11258,
#  'looser': 5945,
#  'waiting': 10940,
#  'weather': 11034,
#  'favorite': 3887,
#  'purchases': 7851,
#  'paired': 7111,
#  'items': 5366,
#  'turtle': 10506,
#  'neck': 6631,
#  'help': 4792,
#  'warm': 10966,
#  'actual': 533,
#  'let': 5766,
#  'dissuade': 3158,
#  'though': 10181,
#  'won': 11234,
#  'decided': 2858,
#  'keeping': 5500,
#  'sized': 9040,
#  'according': 507,
#  'reviews': 8323,
#  'typically': 10543,
#  'fine': 3980,
#  '36b': 303,
#  'fairly': 3818,
#  'photos': 7357,
#  'flare': 4038,
#  'at': 980,
#  'why': 11147,
#  'unsure': 10716,
#  'tailor': 9959,
#  'wrong': 11327,
#  'afraid': 608,
#  'boy': 1534,
#  'elegant': 3460,
#  'night': 6700,
#  'shoes': 8886,
#  'accessories': 485,
#  'anticipating': 807,
#  'spectacular': 9374,
#  'said': 8522,
#  'colorful': 2252,
#  '145': 131,
#  'probably': 7727,
#  'xs': 11338,
#  'hard': 4700,
#  'finding': 3978,
#  'dresses': 3305,
#  'stripe': 9665,
#  'version': 10845,
#  'nautical': 6609,
#  'vibe': 10859,
#  'either': 3447,
#  'antho': 802,
#  'overlooked': 7038,
#  'rather': 7967,
#  'unimpressive': 10677,
#  'hanger': 4685,
#  'across': 523,
#  'shoulders': 8923,
#  'gives': 4447,
#  'mor': 6472,
#  'overpriced': 7046,
#  'uncomfortable': 10588,
#  'utter': 10784,
#  'dismay': 3147,
#  'wore': 11255,
#  'during': 3365,
#  'business': 1711,
#  'trip': 10441,
#  'first': 4003,
#  'bruises': 1638,
#  'caused': 1902,
#  'side': 8956,
#  'zipper': 11424,
#  'shopper': 8893,
#  'ending': 3535,
#  'pain': 7103,
#  'disappointment': 3107,
#  'owned': 7075,
#  'exquisite': 3754,
#  'never': 6673,
#  'write': 11321,
#  'embroidery': 3508,
#  'catch': 1886,
#  'beading': 1199,
#  'handle': 4671,
#  'carefully': 1840,
#  'special': 9364,
#  'treatment': 10413,
#  'intending': 5261,
#  'buy': 1742,
#  'shirts': 8875,
#  'needed': 6643,
#  'nicely': 6689,
#  'thighs': 10154,
#  'find': 3977,
#  'stevie': 9542,
#  'styled': 9715,
#  'ags': 634,
#  'eyeing': 3778,
#  'based': 1164,
#  'wearable': 11026,
#  'function': 4308,
#  'taller': 9975,
#  'despite': 2994,
#  'dot': 3227,
#  'pattern': 7205,
#  'brown': 1630,
#  'booties': 1485,
#  'wow': 11293,
#  'vibrant': 10862,
#  '11': 39,
#  'works': 11268,
#  'case': 1870,
#  'adore': 581,
#  'petite': 7329,
#  'tall': 9974,
#  '120': 71,
#  'curvy': 2736,
#  'untucked': 10722,
#  'disagree': 3096,
#  'frumpy': 4293,
#  'kelly': 5504,
#  'brand': 1556,
#  'slacks': 9085,
#  'coat': 2207,
#  'piping': 7430,
#  'moss': 6483,
#  'suede': 9756,
#  'cross': 2672,
#  'bag': 1098,
#  'neutral': 6671,
#  'nude': 6786,
#  'fl': 4019,
#  'jacket': 5387,
#  'spring': 9431,
#  'tea': 10020,
#  'before': 1238,
#  'after': 611,
#  'workouts': 11265,
#  'thicker': 10148,
#  'sweatshirt': 9882,
#  'issue': 5350,
#  'tule': 10488,
#  'remove': 8177,
#  'those': 10179,
#  'hourglass': 4962,
#  'naturally': 6605,
#  'provide': 7795,
#  'shaping': 8806,
#  'tunic': 10495,
#  'dressed': 3304,
#  'fitted': 4011,
#  'turned': 10499,
#  'oversized': 7054,
#  'muumuu': 6567,
#  'feminine': 3928,
#  '20': 192,
#  'concerned': 2377,
#  'ordering': 6949,
#  'seeing': 8699,
#  'disappoint': 3102,
#  'texture': 10097,
#  'pant': 7142,
#  'unique': 10679,
#  'provides': 7797,
#  'visual': 10894,
#  'appeal': 835,
#  'office': 6852,
#  'place': 7447,
#  'holiday': 4894,
#  'fun': 4307,
#  'plaid': 7454,
#  'your': 11398,
#  'classic': 2117,
#  'button': 1732,
#  'whole': 11141,
#  'trend': 10421,
#  'fau': 3875,
#  'bank': 1145,
#  'classy': 2124,
#  'bare': 1151,
#  'professional': 7744,
#  'setting': 8761,
#  'upscale': 10750,
#  'totally': 10339,
#  'others': 6975,
#  'cobalt': 2210,
#  'armholes': 900,
#  'snatched': 9221,
#  'amazing': 733,
#  'boyfriend': 1535,
#  'run': 8479,
#  'include': 5137,
#  'weigh': 11065,
#  'pounds': 7623,
#  'usual': 10778,
#  'room': 8417,
#  'two': 10536,
#  'sweatshirts': 9883,
#  'unfortunately': 10665,
#  'young': 11396,
#  'coupon': 2571,
#  'slimming': 9131,
#  'broad': 1616,
#  'used': 10769,
#  'solid': 9274,
#  'move': 6510,
#  '00': 0,
#  '115': 53,
#  'tighter': 10239,
#  'peiople': 7254,
#  'choose': 2051,
#  'teh': 10046,
#  'cutis': 2755,
#  'wont': 11244,
#  'matter': 6186,
#  'colros': 2264,
#  'flow': 4121,
#  'romantic': 8411,
#  'forgivin': 4206,
#  'hte': 4984,
#  'covers': 2583,
#  'tushy': 10510,
#  'flared': 4039,
#  'bottoms': 1515,
#  'pencil': 7262,
#  'skiny': 9071,
#  'hesitant': 4817,
#  'double': 3230,
#  'breasted': 1573,
#  'choice': 2043,
#  'least': 5718,
#  'problems': 7732,
#  'sparkle': 9353,
#  'none': 6731,
#  'elements': 3464,
#  'themselves': 10126,
#  'problem': 7729,
#  'sum': 9775,
#  'parts': 7172,
#  'didn': 3043,
#  'end': 3533,
#  'result': 8271,
#  'confusing': 2408,
#  'mess': 6283,
#  'silhouette': 8976,
#  'plus': 7501,
#  'frayed': 4250,
#  'edges': 3419,
#  'sequins': 8750,
#  'vent': 10829,
#  'breast': 1572,
#  'prettier': 7686,
#  'vest': 10853,
#  'quite': 7913,
#  'delicate': 2919,
#  'certainly': 1932,
#  'pick': 7366,
#  'myself': 6571,
#  'lucky': 6005,
#  'steal': 9523,
#  'known': 5570,
#  'paid': 7101,
#  'picked': 7367,
#  'smaller': 9173,
#  'range': 7954,
#  'instead': 5242,
#  'slip': 9137,
#  'tts': 10472,
#  'silk': 8980,
#  'outer': 6991,
#  'flowy': 4133,
#  '36dd': 306,
#  '140': 119,
#  'barrel': 1161,
#  'chested': 2013,
#  'upper': 10746,
#  'bulk': 1674,
#  'per': 7276,
#  'images': 5071,
#  'awkward': 1066,
#  'placement': 7449,
#  'vs': 10913,
#  'structured': 9682,
#  'cape': 1816,
#  'shawl': 8814,
#  'blanket': 1374,
#  'peach': 7224,
#  'waited': 10939,
#  'raspberry': 7963,
#  'come': 2280,
#  'putting': 7876,
#  'cami': 1786,
#  'underneath': 10614,
#  '26': 222,
#  'tend': 10060,
#  '27p': 228,
#  'booty': 1488,
#  'hug': 4994,
#  'places': 7450,
#  'dark': 2798,
#  'thing': 10157,
#  'wedges': 11052,
#  'drag': 3260,
#  'ground': 4607,
#  'arrived': 915,
#  'elbow': 3456,
#  'combo': 2278,
#  'away': 1057,
#  'meant': 6220,
#  'relaxed': 8137,
#  'versatile': 10842,
#  'simple': 8995,
#  'adds': 553,
#  'splurge': 9408,
#  'added': 541,
#  'closet': 2178,
#  'ok': 6866,
#  'recently': 8029,
#  'baby': 1073,
#  'gained': 4340,
#  'process': 7733,
#  'losing': 5954,
#  'took': 10311,
#  'risk': 8378,
#  'buying': 1746,
#  'torso': 10329,
#  'fat': 3868,
#  'rompers': 8414,
#  'impossible': 5100,
#  'lengthwise': 5754,
#  'draping': 3276,
#  'splashy': 9400,
#  'loud': 5962,
#  'review': 8317,
#  'soon': 9300,
#  'realized': 8001,
#  'pu': 7807,
#  'truly': 10454,
#  'brainer': 1549,
#  'stunning': 9708,
#  'rock': 8392,
#  'boots': 1487,
#  '103': 18,
#  'xxs': 11346,
#  'slightly': 9124,
#  'fitting': 4013,
#  'everyth': 3652,
#  'sort': 9315,
#  'pullover': 7828,
#  'poorly': 7563,
#  'once': 6881,
#  'started': 9499,
#  'fray': 4249,
#  'apart': 829,
#  'closely': 2174,
#  'inspecting': 5227,
#  'cause': 1901,
#  'threads': 10190,
#  'fully': 4306,
#  'sewed': 8771,
#  'together': 10292,
#  'minute': 6369,
#  'start': 9498,
#  'unravel': 10700,
#  'leading': 5703,
#  'domino': 3215,
#  'effect': 3428,
#  'shame': 8795,
#  'silvery': 8991,
#  'beige': 1251,
#  'deep': 2877,
#  'plum': 7497,
#  'close': 2172,
#  'highlight': 4841,
#  'curves': 2733,
#  'chic': 2019,
#  'jazzed': 5409,
#  'outfit': 6993,
#  'best': 1295,
#  'perfectly': 7293,
#  'type': 10539,
#  'happened': 4694,
#  'someone': 9287,
#  'purchasing': 7852,
#  'sales': 8529,
#  'associate': 957,
#  'told': 10295,
#  'gone': 4500,
#  'sp': 9335,
#  'says': 8592,
#  'turquoise': 10505,
#  'emerald': 3509,
#  'bright': 1602,
#  'saturated': 8575,
#  'eyes': 3783,
#  'brings': 1611,
#  'know': 5567,
#  'folks': 4171,
#  'teach': 10021,
#  'lightweight': 5810,
#  'beyond': 1306,
#  'darling': 2802,
#  'designer': 2986,
#  'additional': 548,
#  'pieces': 7385,
#  'next': 6686,
#  'season': 8668,
#  'investment': 5308,
#  'graduated': 4546,
#  'college': 2239,
#  'year': 11364,
#  'round': 8440,
#  'flows': 4132,
#  'making': 6086,
#  'wondering': 11240,
#  'wound': 11291,
#  'currently': 2727,
#  'xsp': 11340,
#  'lower': 5989,
#  'stop': 9584,
#  'hesitating': 4821,
#  'wadded': 10923,
#  'shown': 8936,
#  'actuality': 534,
#  'funky': 4317,
#  'beigey': 1252,
#  'sending': 8726,
#  'again': 619,
#  'remind': 8168,
#  'shouldn': 8924,
#  'mail': 6062,
#  'adorable': 580,
#  'hides': 4832,
#  'spots': 9423,
#  'hidden': 4829,
#  'shortly': 8910,
#  'christmas': 2063,
#  'oversize': 7053,
#  'natural': 6604,
#  'clothing': 2186,
#  ...}

# %%
review1.get_feature_names_out()
# Out:
# array(['00', '00p', '02', ..., 'zooming', 'zuma', 'ã¼ber'], dtype=object)

# %% [markdown]
# # Logistic Regression classification
#
# We will train a logistic regression model to classify the  Amazon reviews into positive and negative reviews by using feature matrix.

# %%
from sklearn.metrics import roc_auc_score

# Predict the transformed test documents
predictions = lm.predict(review1.transform(X_test))
y_proba = lm.predict_proba(review1.transform(X_test))

print('AUC: ', roc_auc_score(y_test, y_proba[:,1]))
# Out:
# AUC:  0.9468811638062624

# %%
# coefficient of each keywords
# lower coefficient = -ve review
lm.coef_
# Out:
# array([[-0.13649485,  0.22374376,  0.07265229, ...,  0.01214997,
#          0.00223398,  0.00061616]])

# %%
lm.coef_[0].argsort()
# Out:
# array([4941, 1980, 1063, ...,  284, 9270, 2358])

# %%
# get the feature names as numpy array
feature_names = np.array(review1.get_feature_names_out())

# Sort the coefficients from the model
sorted_coef_index = lm.coef_[0].argsort()

# Find the 10 smallest and 10 largest coefficients
print('Smallest Coefs:' )
print(feature_names[sorted_coef_index[  :10]])

print('\n Largest Coefs:')   #\n is for line space
print(feature_names[sorted_coef_index[  :-11:-1]]) #select last 10 values
# Out:
# Smallest Coefs:
# ['horrible' 'cheap' 'awful' 'completely' 'disappointed' 'poor'
#  'unflattering' 'wanted' 'nothing' 'disappointment']
#
#  Largest Coefs:
# ['compliments' 'sold' '34' 'happy' 'unique' 'paired' 'beautifully'
#  'stunning' 'little' 'deep']

# %% [markdown]
# # Tfidf
#
# When we are analyzing text data, we often encounter words that occur across multiple documents from both classes. Those frequently occurring words typically don't contain useful or discriminatory information. In this subsection, we will learn about a useful technique called **term frequency-inverse document frequency** (*tf-idf*) that can be used to downweight those frequently occurring words in the feature vectors. On the other words by tf-idf we can reduce the weightage of more common words like (the, is, an etc.) which occurs in all document.
#
# The *tf-idf* can be defined as the product of the term frequency and the inverse document frequency:
#
# \begin{align}
# \textit{tf-idf}(t,d) = tf(t,d) \times idf(t,d)
# \end{align}
#
# Here the <font color=green><b> *tf(t,d)* </b></font> is the term frequency that equal to **Count of word / Total words, in each document**. The inverse document frequency *idf(t,d)* can be calculated as:
#
# \begin{align}
# idf(t,d) = log\frac{n_d}{\text{df(d,t)}}
# \end{align}
#
# where <font color=green><b> $n_d$ </b></font> is **the total number of documents**, and <font color=green><b>*df(d,t)*</b></font> is **the number of documents *d* that contain the term t**. Note that the log is used to ensure that low document frequencies are not given too much weight.
#
#
# scikit-learn implements yet another vectorizer, the TfidfVectorizer, that creates feature vectors as tf-idfs.

# %%
# to remove standard english stop words
from sklearn.feature_extraction.text import TfidfVectorizer

docs = np.array([
    'The sun is shining',
    'The weather is sweet',
    'The sun is shining and the weather is sweet'])

vect2 = TfidfVectorizer().fit(docs)
bag2 = vect2.transform(docs)

# trained data is vect2
# bag data is bag2

# %%
vect2.get_feature_names_out()
# Out:
# array(['and', 'is', 'shining', 'sun', 'sweet', 'the', 'weather'],
#       dtype=object)

# %%
vect3 = TfidfVectorizer(min_df=2).fit(docs)
bag3 = vect3.transform(docs)
vect3.get_feature_names_out()
# Out:
# array(['is', 'shining', 'sun', 'sweet', 'the', 'weather'], dtype=object)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Fit the TfidfVectorizer to the training data
review2 = TfidfVectorizer(min_df=5).fit(X_train)
X_train_vectorized2 = review2.fit_transform(X_train)

# %%
len(review2.get_feature_names_out())
# Out:
# 3850

# %%
X_test_vectorized2 = review2.transform(X_test)
X_test_vectorized2.shape
# Out:
# (4300, 3850)

# %%
# Train the Logistic Regression model
model = LogisticRegression()
model.fit(X_train_vectorized2, y_train)

# Evaluate the model on the test data
accuracy = model.score(X_test_vectorized2, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9253488372093023

# %%
X_train_vectorized2 = review2.transform(X_train)

model = LogisticRegression()
model.fit(X_train_vectorized2, y_train)

predictions = model.predict(review2.transform(X_test))
y_proba = model.predict_proba(review2.transform(X_test))

print('AUC: ', roc_auc_score(y_test, y_proba[:,1]))
# Out:
# AUC:  0.9571966710468682

# %% [markdown]
# ## <font color=green> Exercise B</font>
# - Predict two below reviews as negative or positive using our model:
#
#       ['no an issue, phone is working', 'an issue, phone is not working']

# %%
model.predict(review2.transform(['dress is very cute, love this']))
# Out:
# array([1])

# %% [markdown]
# Try this!

# %%
model.predict(review2.transform(['the material is cheap, disappointed even though the design is beautiful']))
# Out:
# array([0])

# %%
# These reviews are now correctly identified
print(model.predict(review3.transform(['dress is very cute, love this',
                                    'the material is cheap, disappointed even though design is beautiful'])))

# %% [markdown]
# # n-grams
#
# The sequence of items in the bag-of-words model that we just created is also called the 1-gram or unigram model — each item or token in the vocabulary represents a single word. Generally, <b>the contiguous sequences of items in NLP</b> — words, letters, or symbols— is also called an n-gram. The choice of the number n in the n-gram model depends on the particular application. For instance, spam filtering applications tend to use n=3 or n=4 for good performances.
# To summarize the concept of the n-gram representation, the 1-gram and 2-gram representations of our first document "the sun is shining" would be constructed as follows:
# - 1-gram: "the", "sun", "is", "shining"
# - 2-gram: "the sun", "sun is", "is shining"
#
# The CountVectorizer class in scikit-learn allows us to use different n-gram models via its ngram_range parameter. By default, it uses a 1-gram representation.

# %%
# Try 2-gram representation
docs = np.array([
    'The sun is shining',
    'The weather is sweet',
    'The sun is shining and the weather is sweet'])

vect3=CountVectorizer(ngram_range=(1,2)).fit(docs)
bag3=vect3.transform(docs)

# %%
vect3.vocabulary_
# Out:
# {'the': 10,
#  'sun': 7,
#  'is': 2,
#  'shining': 5,
#  'the sun': 11,
#  'sun is': 8,
#  'is shining': 3,
#  'weather': 13,
#  'sweet': 9,
#  'the weather': 12,
#  'weather is': 14,
#  'is sweet': 4,
#  'and': 0,
#  'shining and': 6,
#  'and the': 1}

# %%
review3 = CountVectorizer(min_df=5, ngram_range=(1,2)).fit(X_train)

X_train_vectorized3 = review3.transform(X_train)

# %%
len(review3.get_feature_names_out())
# Out:
# 23333

# %%
X_test_vectorized3 = review3.transform(X_test)
X_test_vectorized3.shape
# Out:
# (4300, 23333)

# %%
# Train the Logistic Regression model
model = LogisticRegression()
model.fit(X_train_vectorized3, y_train)

# Evaluate the model on the test data
accuracy = model.score(X_test_vectorized3, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.934186046511628
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
model = LogisticRegression()
model.fit(X_train_vectorized3, y_train)

predictions = model.predict(review3.transform(X_test))
y_proba = model.predict_proba(review3.transform(X_test))

print('AUC: ', roc_auc_score(y_test, y_proba[:,1]))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# AUC:  0.9566195463173124

# %%
feature_names = np.array(review3.get_feature_names_out())

sorted_coef_index = model.coef_[0].argsort()

print('Smallest Coefs:' )
print(feature_names[sorted_coef_index[:10]])

print('\n Largest Coefs:')
print(feature_names[sorted_coef_index[:-11:-1]])
# Out:
# Smallest Coefs:
# ['cheap' 'to love' 'unflattering' 'poor' 'disappointed' 'returned'
#  'not flattering' 'completely' 'awful' 'very disappointed']
#
#  Largest Coefs:
# ['compliments' 'very cute' 'not too' 'little' 'comfortable' 'beautiful'
#  'unique' 'perfect' 'love this' 'great']

# %%
sorted_coef_index
# Out:
# array([ 4051, 20286, 20991, ..., 12897, 21332,  4541])

# %%
# These reviews are now correctly identified
print(model.predict(review3.transform(['dress is very cute, love this',
                                    'the material is cheap, disappointed even though design is beautiful'])))
# Out:
# [1 0]
